# %% [markdown]
# # Exploring poverty measures
#
# Scratch comparison of the headcount rate, the poverty gap and the Gini
# coefficient on a toy income vector. Anything worth keeping moves into
# `src/wb_analytics/`, with tests.

# %%
from wb_analytics.poverty_calc import (
    POVERTY_LINE_USD_PPP,
    gini_coefficient,
    poverty_gap_index,
    poverty_rate,
)

incomes = [0.9, 1.4, 2.1, 2.6, 3.3, 4.8, 7.5, 12.0]
POVERTY_LINE_USD_PPP

# %%
poverty_rate(incomes)

# %%
poverty_gap_index(incomes)

# %%
gini_coefficient(incomes, population=len(incomes))
